# %% [markdown]
# # Data Science 8410: Data Mining and Information Retrieval
#
# ## Syllabus
#
# The course introduces the main concepts and techniques of data mining (DM) and information retrieval (IR). It covers a variety of data mining topics and methods to extract hidden and predictive patterns from large data collections. Furthermore, theory and techniques for the modeling, indexing, and retrieval of relational, non-relational, text-based and multimedia databases is covered. Topics include introduction to data mining process, mining frequent patterns, and pattern analysis, as well as different information retrieval models and evaluation, query languages and operations, indexing/searching methods, and recommender systems.
#
# <span style="background-color:yellow">See the Canvas course site for the syllabus, grading and other important information.</span>
#
# ## Objectives
#
# Upon successful completion of this course students will be able to:
#
# 1. Understand basic concepts, principles, and methods in data mining and information retrieval as well as obtain hands-on experience using data mining and information retrieval toolkits tailored for big data and clouds
# 2. Apply various document analytics methods including traditional (e.g. clustering and classification) and advanced (e.g., topic modeling and sentiment analysis) to various data sets, especially to textual data
# 3. Recall important pattern discovery concepts, methods, and applications, in particular, the basic concepts of pattern discovery, such as frequent pattern, closed pattern, max-pattern, and association rules.
# 4. Learn the underlying technologies of classical and modern information retrieval system
# 5. Understand basic concepts and methods of recommender systems

# %% [markdown]
# # This is a test cell

# %% [markdown]
# ## Books
#
# 1. [Data Mining and Machine Learning: Fundamental Concepts and Algorithms](https://dataminingbook.info/) [Free]
# 1. [Introduction to Information Retrieval](https://nlp.stanford.edu/IR-book/information-retrieval-book.html) [Free]

# %% [markdown]
# <span style="background-color:yellow">**Note: Use DMIR container for your coursework.**</span>
#
# ## Course Schedule
#
#
#  * [1: Introduction to DMIR + Classification](./module1/Schedule.ipynb)
#  * [2: Clustering](./module2/Schedule.ipynb)
#  * [3: Pattern Mining - I](./module3/Schedule.ipynb)
#  * [4: Pattern Mining - II](./module4/Schedule.ipynb)
#  * [5: Information Retrieval - I](./module5/Schedule.ipynb)
#  * [6: Information Retrieval - II](./module6/Schedule.ipynb)
#  * [7: Advanced Document Analytics](./module7/Schedule.ipynb)
#  * [8: Recommender systems](./module8/Schedule.ipynb)
#
# ### Pulling course work
# New modules will be available on Monday of each week. To pull new material:
# 1. open a terminal
# 1. change to the course directory:
# `cd f20dsa8410*`
# 1. pull new material from the upstream master repository without supplying a custom merge message:
# `git pull --no-edit upstream master`

# %% [markdown]
# ## Course Links
#  * [Canvas-online](https://umsystem.instructure.com/courses/8188)
#  * [Canvas-oncampus](https://umsystem.instructure.com/courses/11411)
#  * [Git Lab](https://git.dsa.missouri.edu/)
#  * Mutal Aid: [Slack #dmir-online-fall-21](https://datagoggles.slack.com/archives/C02BWNVJK9Q)
